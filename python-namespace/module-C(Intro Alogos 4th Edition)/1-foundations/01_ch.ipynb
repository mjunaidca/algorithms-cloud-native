# %% [markdown]
# Exercises
# 1.1-1
# Describe your own real-world example that requires sorting. Describe one that requires ûnding the shortest distance between two points.
#
# 1.1-2
# Other than speed, what other measures of efûciency might you need to consider in a real-world setting?
#
# 1.1-3
# Select a data structure that you have seen, and discuss its strengths and limitations.
#
# 1.1-4
# How are the shortest-path and traveling-salesperson problems given above similar? How are they different?
#
# 1.1-5
# Suggest a real-world problem in which only the best solution will do. Then come up with one in which <approximately= the best solution is good enough.
#
# 1.1-6
# Describe a real-world problem in which sometimes the entire input is available before you need to solve the problem, but other times the input is not entirely available in advance and arrives over time.

# %% [markdown]
# ### 1.1-1
# **Real-world example requiring sorting:**
# Imagine you're managing a library, and new books arrive daily. To make it easier for patrons to find the books they need, you must arrange them in alphabetical order by author last name or title. This sorting process ensures that books are quickly and efficiently located.
#
# **Real-world example requiring finding the shortest distance between two points:**
# Consider a delivery driver who needs to drop off packages at multiple locations in a city. The driver wants to find the shortest possible route from the warehouse to each delivery point to minimize travel time and fuel consumption.
#
# ### 1.1-2
# **Other measures of efficiency to consider:**
# - **Memory Usage:** How much memory does the algorithm consume while executing? This is crucial for devices with limited memory resources.
# - **Scalability:** How well does the algorithm perform as the size of the input data increases? This is important for applications that deal with large datasets.
# - **Energy Consumption:** Especially in mobile or embedded systems, the amount of energy consumed by the algorithm can be a critical factor.
# - **Robustness:** The ability of the algorithm to handle unexpected input or scenarios without failing.
# - **Ease of Implementation and Maintenance:** How easy is it to implement, understand, and maintain the algorithm? This can affect the long-term viability of a solution.
#
# ### 1.1-3
# **Data Structure: Hash Table**
# - **Strengths:**
#   - **Fast Access:** Provides average-case O(1) time complexity for search, insert, and delete operations, making it very efficient for these tasks.
#   - **Ease of Use:** Simple to implement for basic key-value storage needs.
# - **Limitations:**
#   - **Collisions:** Although collisions (where two keys hash to the same index) can be managed with techniques like chaining or open addressing, they can degrade performance.
#   - **Memory Usage:** Hash tables can require more memory than other data structures, especially if the load factor is kept low to minimize collisions.
#   - **Ordering:** Hash tables do not maintain any order of elements, so if ordered data retrieval is required, another data structure might be more appropriate.
#
# ### 1.1-4
# **Similarities between the shortest-path and traveling-salesperson problems:**
# - Both problems involve finding an optimal path in a graph.
# - They require consideration of distances or costs between points and aim to minimize the total distance or cost.
#
# **Differences:**
# - The **shortest-path problem** seeks the shortest path between two specific points. It focuses on finding the most efficient way to get from point A to point B.
# - The **traveling-salesperson problem (TSP)** requires finding the shortest possible route that visits every point exactly once and returns to the starting point. TSP is more complex and involves considering the entire set of points.
#
# ### 1.1-5
# **Problem requiring the best solution:**
# - **Example:** Designing a pacemaker. The device must function correctly at all times because any failure could have serious or fatal consequences. Only the best, most reliable solution is acceptable.
#
# **Problem where an approximately best solution is good enough:**
# - **Example:** Streaming video quality. In many cases, a high-definition (HD) video is good enough for viewers. While 4K might be better, it's not necessary for everyone, and a slightly lower resolution will still provide a satisfactory experience.
#
# ### 1.1-6
# **Real-world problem with varying input availability:**
# - **Example:** Stock market analysis. Sometimes, you might have all the historical data needed to make an investment decision in advance. However, other times, new information about market conditions, company earnings, or economic events arrives continuously throughout the day. You must update your strategy in real-time as this new data becomes available.

# %% [markdown]
# 1.2-1
# Give an example of an application that requires algorithmic content at the applica-
# on a particular computer, insertion sort runs in
# lg steps. For which values of does insertion
# tion level, and discuss the function of the algorithms involved.
#
# 1.2-2
# Suppose that for inputs of size steps and merge sort runs in sort beat merge sort?
#
# 1.2-3
# such that an algorithm whose running time is
# For each function and time in the following table, determine the largest size of a problem that can be solved in time , assuming that the algorithm to solve the problem takes microseconds.
# What is the smallest value of
# runs faster than an algorithm whose running time is on the same machine?
#
# 1-1 Comparison of running times
# n001

# %% [markdown]
# 1.2-1
# Example of an application requiring algorithmic content:
# Consider a navigation app like Google Maps. The app uses several algorithms to function effectively:
#
# Shortest Path Algorithm: To find the quickest route from your current location to your destination, algorithms like Dijkstra's or A* are used.
# Traffic Prediction Algorithm: The app predicts traffic conditions using machine learning models that analyze historical data and real-time inputs.
# Map Rendering Algorithm: Algorithms are used to efficiently render maps on the screen, ensuring smooth scrolling and zooming.
# These algorithms work together to provide a seamless user experience, from routing to real-time updates and map visualization.
#
# 1.2-2
# Suppose insertion sort runs in
# 𝑛
# 2
# n
# 2
#   steps and merge sort runs in
# 𝑛
# log
# ⁡
# 𝑛
# nlogn steps. We want to find the value of
# 𝑛
# n for which insertion sort runs faster than merge sort.
#
# We compare the two functions
# 𝑛
# 2
# n
# 2
#   and
# 𝑛
# log
# ⁡
# 𝑛
# nlogn. The crossover point occurs where
# 𝑛
# 2
# =
# 𝑛
# log
# ⁡
# 𝑛
# n
# 2
#  =nlogn.
#
# To estimate this, we can solve the inequality:
#
# 𝑛
# 2
# <
# 𝑛
# log
# ⁡
# 𝑛
# n
# 2
#  <nlogn
# For large values of
# 𝑛
# n,
# 𝑛
# log
# ⁡
# 𝑛
# nlogn grows slower than
# 𝑛
# 2
# n
# 2
#  , meaning insertion sort will only be faster for very small values of
# 𝑛
# n. Typically, this crossover occurs around
# 𝑛
# =
# 10
# n=10 or smaller, depending on the exact constants involved in the implementations.
#
# 1.2-3
# To determine the largest size of a problem that can be solved in time
# 𝑇
# T, given that the algorithm takes
# 𝑇
# (
# 𝑛
# )
# T(n) microseconds, we need to solve for
# 𝑛
# n in terms of the time available.
#
# Given functions
# 𝑇
# (
# 𝑛
# )
# T(n) and maximum time
# 𝑇
# T, we solve:
#
# 𝑇
# (
# 𝑛
# )
# ≤
# 𝑇
# T(n)≤T
# Here’s a breakdown of how you can determine
# 𝑛
# n for each common complexity class:
#
# Time Complexity	Function
# 𝑇
# (
# 𝑛
# )
# T(n)	Equation
# 𝑇
# (
# 𝑛
# )
# ≤
# 𝑇
# T(n)≤T	Solution for
# 𝑛
# n
# 𝑂
# (
# 1
# )
# O(1)	Constant time
# 1
# ≤
# 𝑇
# 1≤T	Any
# 𝑛
# n
# 𝑂
# (
# log
# ⁡
# 𝑛
# )
# O(logn)	Logarithmic
# log
# ⁡
# 𝑛
# ≤
# 𝑇
# logn≤T
# 𝑛
# ≤
# 2
# 𝑇
# n≤2
# T
#
# 𝑂
# (
# 𝑛
# )
# O(n)	Linear
# 𝑛
# ≤
# 𝑇
# n≤T
# 𝑛
# =
# 𝑇
# n=T
# 𝑂
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# O(nlogn)	Linearithmic
# 𝑛
# log
# ⁡
# 𝑛
# ≤
# 𝑇
# nlogn≤T	Solve numerically
# 𝑂
# (
# 𝑛
# 2
# )
# O(n
# 2
#  )	Quadratic
# 𝑛
# 2
# ≤
# 𝑇
# n
# 2
#  ≤T
# 𝑛
# ≤
# 𝑇
# n≤
# T
# ​
#
# 𝑂
# (
# 2
# 𝑛
# )
# O(2
# n
#  )	Exponential
# 2
# 𝑛
# ≤
# 𝑇
# 2
# n
#  ≤T
# 𝑛
# ≤
# log
# ⁡
# 2
# 𝑇
# n≤log
# 2
# ​
#  T
# Example with Specific Values
# If
# 𝑇
# =
# 1
# 0
# 6
# T=10
# 6
#   microseconds:
#
# For
# 𝑂
# (
# 𝑛
# 2
# )
# O(n
# 2
#  ):
# 𝑛
# ≤
# 1
# 0
# 6
# =
# 1000
# n≤
# 10
# 6
#
# ​
#  =1000.
# For
# 𝑂
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# O(nlogn): Solve numerically, e.g.,
# 𝑛
# log
# ⁡
# 𝑛
# ≈
# 1
# 0
# 6
# nlogn≈10
# 6
#  . This gives
# 𝑛
# n slightly less than 100,000.
# For
# 𝑂
# (
# 2
# 𝑛
# )
# O(2
# n
#  ):
# 𝑛
# ≤
# log
# ⁡
# 2
# 1
# 0
# 6
# ≈
# 19.93
# n≤log
# 2
# ​
#  10
# 6
#  ≈19.93, so
# 𝑛
# n can be at most 19.
# 1.2-4
# To determine when an algorithm with running time
# 𝑇
# (
# 𝑛
# )
# T(n) is faster than another algorithm with running time
# 𝑆
# (
# 𝑛
# )
# S(n), find the smallest value of
# 𝑛
# n where
# 𝑇
# (
# 𝑛
# )
# <
# 𝑆
# (
# 𝑛
# )
# T(n)<S(n).
#
# For example, if
# 𝑇
# (
# 𝑛
# )
# =
# 𝑛
# log
# ⁡
# 𝑛
# T(n)=nlogn and
# 𝑆
# (
# 𝑛
# )
# =
# 𝑛
# 2
# S(n)=n
# 2
#  , we solve:
#
# 𝑛
# log
# ⁡
# 𝑛
# <
# 𝑛
# 2
# nlogn<n
# 2
#
# Simplifying:
#
# log
# ⁡
# 𝑛
# <
# 𝑛
# logn<n
# The smallest
# 𝑛
# n where
# log
# ⁡
# 𝑛
# <
# 𝑛
# logn<n happens for
# 𝑛
# ≥
# 2
# n≥2, meaning for
# 𝑛
# ≥
# 2
# n≥2, the algorithm with
# 𝑛
# log
# ⁡
# 𝑛
# nlogn runs faster than the algorithm with
# 𝑛
# 2
# n
# 2
#  .
#
# 1-1 Comparison of Running Times
# Here’s a rough comparison of different time complexities and how they scale:
#
# Time Complexity	Growth Rate
# 𝑂
# (
# 1
# )
# O(1)	Constant
# 𝑂
# (
# log
# ⁡
# 𝑛
# )
# O(logn)	Logarithmic
# 𝑂
# (
# 𝑛
# )
# O(n)	Linear
# 𝑂
# (
# 𝑛
# log
# ⁡
# 𝑛
# )
# O(nlogn)	Linearithmic
# 𝑂
# (
# 𝑛
# 2
# )
# O(n
# 2
#  )	Quadratic
# 𝑂
# (
# 2
# 𝑛
# )
# O(2
# n
#  )	Exponential
# 𝑂
# (
# 𝑛
# !
# )
# O(n!)	Factorial
# For small inputs, algorithms with higher complexity might still be feasible, but as input size grows, exponential or factorial complexities become impractical very quickly.
